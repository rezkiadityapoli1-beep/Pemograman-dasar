# %% [markdown]
# <a href="https://colab.research.google.com/github/rezkiadityapoli1-beep/Pemograman-dasar/blob/main/Pertemuan_1_malam_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama="Muhammad Rezki Aditya"
umur=21
jurusan="Elektro"
prodi="TRPE"
semester=3
matakuliah="Pemerograman Dasar"
status_lulus=False
hobi = "futsal"
alamat = "tanjung sengkuang batu ampar"

print(nama)
print(umur)
print(jurusan)
print(prodi)
print(semester)
print(matakuliah)
print(status_lulus)
print(hobi)
print(alamat)
# Out:
# Muhammad Rezki Aditya
# 21
# Elektro
# TRPE
# 3
# Pemerograman Dasar
# False
# futsal
# tanjung sengkuang batu ampar

# %%
nama="Muhammad Rezki Aditya"
umur=21
jumlahsaudara =3
jurusan="Elektro"
prodi="TRPE"
semester=3
matakuliah="Pemerograman Dasar"
status_lulus=False
hobi = "futsal"
alamat = "tanjung sengkuang batu ampar"

print(nama)
print(umur)
print(jumlahsaudara)
print(jurusan)
print(prodi)
print(semester)
print(matakuliah)
print(status_lulus)
print(hobi)
print(alamat)
# Out:
# Muhammad Rezki Aditya
# 21
# 3
# Elektro
# TRPE
# 3
# Pemerograman Dasar
# False
# futsal
# tanjung sengkuang batu ampar

# %%
nama="Muhammad Rezki Aditya"
umur=21
jurusan="Elektro"
prodi="TRPE"
semester=3
matakuliah="Pemerograman Dasar"
status_lulus=False
hobi = "futsal"
alamat = "tanjung sengkuang batu ampar"

print(nama)
print(umur)
print(jurusan)
print(prodi)
print(semester)
print(matakuliah)
print(status_lulus)
print(hobi)
print(alamat)
# Out:
# Muhammad Rezki Aditya
# 21
# Elektro
# TRPE
# 3
# Pemerograman Dasar
# False
# futsal
# tanjung sengkuang batu ampar
